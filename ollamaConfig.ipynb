# %%
import ollama

# %%
prompt = "AUm Was working at moon finance"

# %%
code_prompt_new = f"Convert this natural language to a Cypher query: {prompt}"

# %%
code_prompt = f"You're a Senior Software Engineer who is very good with converting natural language to cypher queries. Your task is to generate a cypher query for this natural language (Here is the natural language description): {prompt}"

# %%
response = ollama.generate(model='gpt-oss:20b', prompt=code_prompt_new)

# %%
print(response['response'])
# Out:
# Sure! Assuming a typical Neo4j model where people are nodes labeled `:Person`, companies are nodes labeled `:Company`, and the relationship between them is `:WORKS_AT`, the Cypher query to find “AUm” working at “moon finance” would look like this:
#
# ```cypher
# // Find the person named AUm who worked at the company moon finance
# MATCH (p:Person {name: "AUm"})-[:WORKS_AT]->(c:Company {name: "moon finance"})
# RETURN p, c;
# ```
#
# If you only care about the person node, you can drop the company from the return clause:
#
# ```cypher
# MATCH (p:Person {name: "AUm"})-[:WORKS_AT]->(c:Company {name: "moon finance"})
# RETURN p;
# ```
#
# **A few notes:**
#
# 1. **Node labels (`:Person`, `:Company`)** – Adjust these if your schema uses different labels.
# 2. **Property names (`name`)** – If your nodes use a different property for the person's name or the company's name, replace `name` accordingly.
# ...

# %%
import ollama

# %%
prompt = "AUm Was working at moon finance"

# %%
code_prompt = f"You're a Senior Software Engineer who is very good with converting natural language to cypher queries. Your task is to generate a cypher query for this natural language (Here is the natural language description): {prompt}"
response = ollama.generate(model='gpt-oss:20b', prompt=code_prompt)

# %%
print(response['response'])
# Out:
# **Cypher query**
#
# ```cypher
# // Create or find the person and company nodes
# MERGE (p:Person {name: 'AUm'})
# MERGE (c:Company {name: 'moon finance'})
#
# // Create the employment relationship (if it doesn't already exist)
# MERGE (p)-[:WORKED_AT]->(c);
# ```
#
# **Explanation**
#
# - `MERGE (p:Person {name: 'AUm'})` guarantees a `Person` node with the name “AUm”.
# - `MERGE (c:Company {name: 'moon finance'})` guarantees a `Company` node with the name “moon finance”.
# - `MERGE (p)-[:WORKED_AT]->(c)` creates (or leaves unchanged if already present) a relationship indicating that the person worked at the company.
